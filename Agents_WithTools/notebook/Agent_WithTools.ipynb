# %%
from langchain.tools import tool
from langchain.agents import create_agent
from langchain.messages import SystemMessage, HumanMessage

# %%
@tool
def get_weather(city: str) -> str:
    """Get weather information for a location."""
    """Returns the current weather for a given city."""
    # In a real application, this would call a weather API
    if city == "Hyderabad":
        return "The weather in Hyderabad is sunny with 79°F."
    else:
        return "Sorry, I do not know the weather for that city."

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
model = "gpt-5"
agent = create_agent(model, tools=[get_weather])

# %%
system_prompt=SystemMessage(
        content=[
            {
                "type": "text",
                "text": "You are an AI assistant tasked with providing weather forecast."
            }])

# %%
query = "Impact of social media on modern literature."
result = agent.invoke(
    {"messages": [ system_prompt,HumanMessage("get the weather in Hyderabad")]}
)

# %%
print(result)
# Out:
# {'messages': [SystemMessage(content=[{'type': 'text', 'text': 'You are an AI assistant tasked with providing weather forecast.'}], additional_kwargs={}, response_metadata={}, id='06f689b6-614c-46e0-a753-4b3fe1babad8'), HumanMessage(content='get the weather in Hyderabad', additional_kwargs={}, response_metadata={}, id='46b50a0a-8748-476d-80d5-d63dc175b561'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 152, 'prompt_tokens': 144, 'total_tokens': 296, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtTCQxZl2sU0KQoOFcvwVZf54PtgP', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b7d74-150f-78a0-ad8c-85642a6bace5-0', tool_calls=[{'name': 'get_weather', 'args': {'city': 'Hyderabad'}, 'id': 'call_Lsp0AuPTUT2eNAnRbOpCkI7Q', 'type': 'tool_call'}], usage_metadata={'input_tokens': 144, 'output_tokens': 152, 'total_tokens': 296, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}), ToolMessage(content='The weather in Hyderabad is sunny with 79°F.', name='get_weather', id='f294fba8-7590-4302-a208-be5355025bff', tool_call_id='call_Lsp0AuPTUT2eNAnRbOpCkI7Q'), AIMessage(content='Hyderabad weather: Sunny, 79°F (about 26°C). Would you like the hourly or 7-day forecast?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 291, 'prompt_tokens': 184, 'total_tokens': 475, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtTCTS7qBIQQ2prs1Wq3MkdIVjJwL', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b7d74-21c4-7793-8629-4ac90812ec4c-0', usage_metadata={'input_tokens': 184, 'output_tokens': 291, 'total_tokens': 475, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}})]}

# %%
len(result)
# Out:
# 1

# %%
result
# Out:
# {'messages': [SystemMessage(content=[{'type': 'text', 'text': 'You are an AI assistant tasked with providing weather forecast.'}], additional_kwargs={}, response_metadata={}, id='06f689b6-614c-46e0-a753-4b3fe1babad8'),
#   HumanMessage(content='get the weather in Hyderabad', additional_kwargs={}, response_metadata={}, id='46b50a0a-8748-476d-80d5-d63dc175b561'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 152, 'prompt_tokens': 144, 'total_tokens': 296, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtTCQxZl2sU0KQoOFcvwVZf54PtgP', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b7d74-150f-78a0-ad8c-85642a6bace5-0', tool_calls=[{'name': 'get_weather', 'args': {'city': 'Hyderabad'}, 'id': 'call_Lsp0AuPTUT2eNAnRbOpCkI7Q', 'type': 'tool_call'}], usage_metadata={'input_tokens': 144, 'output_tokens': 152, 'total_tokens': 296, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}),
#   ToolMessage(content='The weather in Hyderabad is sunny with 79°F.', name='get_weather', id='f294fba8-7590-4302-a208-be5355025bff', tool_call_id='call_Lsp0AuPTUT2eNAnRbOpCkI7Q'),
#   AIMessage(content='Hyderabad weather: Sunny, 79°F (about 26°C). Would you like the hourly or 7-day forecast?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 291, 'prompt_tokens': 184, 'total_tokens': 475, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtTCTS7qBIQQ2prs1Wq3MkdIVjJwL', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b7d74-21c4-7793-8629-4ac90812ec4c-0', usage_metadata={'input_tokens': 184, 'output_tokens': 291, 'total_tokens': 475, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}})]}

# %%
result['messages'][0].content
# Out:
# [{'type': 'text',
#   'text': 'You are an AI assistant tasked with providing weather forecast.'}]

# %%
print(result['messages'][0].content)
# Out:
# [{'type': 'text', 'text': 'You are an AI assistant tasked with providing weather forecast.'}]

# %%
result['messages'][-1].content
# Out:
# 'Hyderabad weather: Sunny, 79°F (about 26°C). Would you like the hourly or 7-day forecast?'

# %%
print(result['messages'][-1].content)
# Out:
# Hyderabad weather: Sunny, 79°F (about 26°C). Would you like the hourly or 7-day forecast?
