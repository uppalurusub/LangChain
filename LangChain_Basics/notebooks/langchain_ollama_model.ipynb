# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(
    model="llama3.2",      # any installed ollama model
    temperature=0.2
)

# %%
response = llm.invoke("Explain transformers in simple terms")

# %%
print(response)
# Out:
# content='Transformers are a type of artificial intelligence (AI) model that\'s used for natural language processing (NLP). Here\'s a simplified explanation:\n\n**What is a Transformer?**\n\nImagine you\'re trying to understand a sentence, like "The cat sat on the mat." A traditional AI model would look at each word individually and try to figure out its meaning. But what if it could look at the entire sentence as a whole and understand how all the words relate to each other?\n\nThat\'s where transformers come in. They\'re designed to process input data (like text) in a way that allows them to capture relationships between different parts of the data.\n\n**How do Transformers work?**\n\nTransformers use something called "attention mechanisms" to focus on specific parts of the input data. Here\'s how it works:\n\n1. The model takes in a sequence of words, like "The cat sat on the mat."\n2. It looks at each word individually and asks itself, "What does this word mean in relation to the other words?"\n3. Instead of looking at individual words, the model uses attention mechanisms to focus on specific parts of the input data that are relevant to each word.\n4. The model then combines these focused parts to create a representation of the entire sentence.\n\n**Key benefits**\n\nTransformers have several advantages over traditional AI models:\n\n* **Improved performance**: Transformers can handle longer sequences of text and perform better than traditional models on tasks like language translation, question answering, and text generation.\n* **Increased efficiency**: Transformers use fewer parameters (the building blocks of a model) than traditional models, making them faster to train and more efficient to use.\n\n**Real-world applications**\n\nTransformers have many practical applications:\n\n* Language translation: Use transformers to translate languages in real-time.\n* Chatbots: Use transformers to power chatbots that can understand and respond to user queries.\n* Text summarization: Use transformers to summarize long documents or articles into concise summaries.\n\nIn summary, transformers are a type of AI model that allows computers to process natural language data more efficiently and effectively. They\'re designed to capture relationships between different parts of the input data, making them powerful tools for tasks like language translation, question answering, and text generation.' additional_kwargs={} response_metadata={'model': 'llama3.2', 'created_at': '2026-01-02T09:12:08.7287115Z', 'done': True, 'done_reason': 'stop', 'total_duration': 50278374900, 'load_duration': 5565412900, 'prompt_eval_count': 31, 'prompt_eval_duration': 1756527900, 'eval_count': 448, 'eval_duration': 42623759300, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'} id='lc_run--019b7df9-c09f-7500-8daa-3811cd80ba03-0' usage_metadata={'input_tokens': 31, 'output_tokens': 448, 'total_tokens': 479}

# %%
print(response.content)
# Out:
# Transformers are a type of artificial intelligence (AI) model that's used for natural language processing (NLP). Here's a simplified explanation:
#
# **What is a Transformer?**
#
# Imagine you're trying to understand a sentence, like "The cat sat on the mat." A traditional AI model would look at each word individually and try to figure out its meaning. But what if it could look at the entire sentence as a whole and understand how all the words relate to each other?
#
# That's where transformers come in. They're designed to process input data (like text) in a way that allows them to capture relationships between different parts of the data.
#
# **How do Transformers work?**
#
# Transformers use something called "attention mechanisms" to focus on specific parts of the input data. Here's how it works:
#
# 1. The model takes in a sequence of words, like "The cat sat on the mat."
# 2. It looks at each word individually and asks itself, "What does this word mean in relation to the other words?"
# 3. Instead of looking at individual words, the model uses attention mechanisms to focus on specific parts of the input data that are relevant to each word.
# 4. The model then combines these focused parts to create a representation of the entire sentence.
#
# **Key benefits**
#
# Transformers have several advantages over traditional AI models:
#
# * **Improved performance**: Transformers can handle longer sequences of text and perform better than traditional models on tasks like language translation, question answering, and text generation.
# * **Increased efficiency**: Transformers use fewer parameters (the building blocks of a model) than traditional models, making them faster to train and more efficient to use.
#
# **Real-world applications**
#
# Transformers have many practical applications:
#
# * Language translation: Use transformers to translate languages in real-time.
# * Chatbots: Use transformers to power chatbots that can understand and respond to user queries.
# * Text summarization: Use transformers to summarize long documents or articles into concise summaries.
#
# In summary, transformers are a type of AI model that allows computers to process natural language data more efficiently and effectively. They're designed to capture relationships between different parts of the input data, making them powerful tools for tasks like language translation, question answering, and text generation.
